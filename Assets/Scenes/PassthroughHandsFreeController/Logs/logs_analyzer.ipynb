# %%
import pandas as pd
import matplotlib as plt
import json
import re

# %%
json_str = "{ \"point_a\" : \"(0,3)\" }"

obj = json.loads(json_str)

print(obj)
# Out:
# {'point_a': '(0,3)'}

# %%
point = re.sub(r'[()]',"",obj['point_a'])
a = list(map(int,point.split(',')))
